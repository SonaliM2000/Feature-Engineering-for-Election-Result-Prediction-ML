# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('major_project.xlsx')
df.columns = df.columns.str.replace('\n',' ')

# %%
df
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER CRIMINAL CASES   AGE CATEGORY      EDUCATION  \
# 0     Lotus   MALE             52  52.0       ST      12th Pass
# 1       Car   MALE              0  54.0       ST  Post Graduate
# 2      Hand   MALE              3  52.0       ST      12th Pass
# 3       NaN    NaN            NaN   NaN      NaN            NaN
# 4     Lotus   MALE              5  58.0       SC      Doctorate
# ...     ...    ...            ...   ...      ...            ...
# 2258   SHIP   MALE              0  43.0  GENERAL  Post Graduate
# 2259    Car   MALE             18  63.0  GENERAL       Graduate
# 2260   Hand   MALE              0  49.0  GENERAL  Post Graduate
# 2261  Lotus   MALE              3  47.0  GENERAL      12th Pass
# 2262    NaN    NaN            NaN   NaN      NaN            NaN
#
#                                 ASSETS                  LIABILITIES  \
# 0            Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+
# 1          Rs 1,84,77,888\n ~ 1 Crore+      Rs 8,47,000\n ~ 8 Lacs+
# 2          Rs 3,64,91,000\n ~ 3 Crore+  Rs 1,53,00,000\n ~ 1 Crore+
# 3                                  NaN                          NaN
# 4          Rs 7,42,74,036\n ~ 7 Crore+    Rs 86,06,522\n ~ 86 Lacs+
# ...                                ...                          ...
# 2258         Rs 48,90,000\n ~ 48 Lacs+    Rs 10,20,000\n ~ 10 Lacs+
# 2259  Rs 1,28,78,51,556\n ~ 128 Crore+  Rs 1,15,35,000\n ~ 1 Crore+
# 2260     Rs 90,36,63,001\n ~ 90 Crore+                     Rs 0\n ~
# 2261       Rs 5,85,77,327\n ~ 5 Crore+    Rs 52,50,000\n ~ 52 Lacs+
# 2262                               NaN                          NaN
#
#       GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0            376892           482       377374
# 1            318665           149       318814
# 2            314057           181       314238
# 3             13030             6        13036
# 4            644459          2416       646875
# ...             ...           ...          ...
# 2258          14661            25        14686
# 2259         434066           178       434244
# 2260         427900           115       428015
# 2261         138731           216       138947
# 2262          11138             2        11140
#
#       OVER TOTAL ELECTORS  IN CONSTITUENCY  \
# 0                                25.330684
# 1                                21.399929
# 2                                21.092771
# 3                                 0.875023
# 4                                33.383823
# ...                                    ...
# 2258                              0.766419
# 2259                             28.975369
# 2260                             28.559732
# 2261                              9.271379
# 2262                              0.743328
#
#       OVER TOTAL VOTES POLLED  IN CONSTITUENCY  TOTAL ELECTORS
# 0                                    35.468248         1489790
# 1                                    29.964370         1489790
# 2                                    29.534285         1489790
# 3                                     1.225214         1489790
# 4                                    56.464615         1937690
# ...                                        ...             ...
# 2258                                  1.250060         1916185
# 2259                                 41.574183         1498666
# 2260                                 40.977823         1498666
# 2261                                 13.302678         1498666
# 2262                                  1.066535         1498666
#
# [2263 rows x 19 columns]

# %%
df.corr()
# Out:
#                                             WINNER       AGE  GENERAL VOTES  \
# WINNER                                    1.000000  0.110294       0.725678
# AGE                                       0.110294  1.000000       0.208567
# GENERAL VOTES                             0.725678  0.208567       1.000000
# POSTAL VOTES                              0.520286  0.129360       0.616742
# TOTAL VOTES                               0.726125  0.208600       0.999988
# OVER TOTAL ELECTORS  IN CONSTITUENCY      0.738976  0.207304       0.962219
# OVER TOTAL VOTES POLLED  IN CONSTITUENCY  0.757303  0.223700       0.962905
# TOTAL ELECTORS                            0.038107  0.021083       0.211092
#
#                                           POSTAL VOTES  TOTAL VOTES  \
# WINNER                                        0.520286     0.726125
# AGE                                           0.129360     0.208600
# GENERAL VOTES                                 0.616742     0.999988
# POSTAL VOTES                                  1.000000     0.620614
# TOTAL VOTES                                   0.620614     1.000000
# OVER TOTAL ELECTORS  IN CONSTITUENCY          0.630882     0.962441
# OVER TOTAL VOTES POLLED  IN CONSTITUENCY      0.634896     0.963150
# TOTAL ELECTORS                                0.038453     0.210515
#
#                                           OVER TOTAL ELECTORS  IN CONSTITUENCY  \
# WINNER                                                                0.738976
# AGE                                                                   0.207304
# GENERAL VOTES                                                         0.962219
# POSTAL VOTES                                                          0.630882
# TOTAL VOTES                                                           0.962441
# OVER TOTAL ELECTORS  IN CONSTITUENCY                                  1.000000
# OVER TOTAL VOTES POLLED  IN CONSTITUENCY                              0.977416
# TOTAL ELECTORS                                                        0.009227
#
#                                           OVER TOTAL VOTES POLLED  IN CONSTITUENCY  \
# WINNER                                                                    0.757303
# AGE                                                                       0.223700
# GENERAL VOTES                                                             0.962905
# POSTAL VOTES                                                              0.634896
# TOTAL VOTES                                                               0.963150
# OVER TOTAL ELECTORS  IN CONSTITUENCY                                      0.977416
# OVER TOTAL VOTES POLLED  IN CONSTITUENCY                                  1.000000
# TOTAL ELECTORS                                                            0.072228
#
#                                           TOTAL ELECTORS
# WINNER                                          0.038107
# AGE                                             0.021083
# GENERAL VOTES                                   0.211092
# POSTAL VOTES                                    0.038453
# TOTAL VOTES                                     0.210515
# OVER TOTAL ELECTORS  IN CONSTITUENCY            0.009227
# OVER TOTAL VOTES POLLED  IN CONSTITUENCY        0.072228
# TOTAL ELECTORS                                  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df.describe()
# Out:
#             WINNER          AGE  GENERAL VOTES  POSTAL VOTES   TOTAL VOTES  \
# count  2263.000000  2018.000000   2.263000e+03   2263.000000  2.263000e+03
# mean      0.238179    52.273538   2.615991e+05    990.710561  2.625898e+05
# std       0.426064    11.869373   2.549906e+05   1602.839174  2.559822e+05
# min       0.000000    25.000000   1.339000e+03      0.000000  1.342000e+03
# 25%       0.000000    43.250000   2.103450e+04     57.000000  2.116250e+04
# 50%       0.000000    52.000000   1.539340e+05    316.000000  1.544890e+05
# 75%       0.000000    61.000000   4.858040e+05   1385.000000  4.872315e+05
# max       1.000000    86.000000   1.066824e+06  19367.000000  1.068569e+06
#
#        OVER TOTAL ELECTORS  IN CONSTITUENCY  \
# count                           2263.000000
# mean                              15.811412
# std                               14.962861
# min                                0.097941
# 25%                                1.296518
# 50%                               10.510553
# 75%                               29.468185
# max                               51.951012
#
#        OVER TOTAL VOTES POLLED  IN CONSTITUENCY  TOTAL ELECTORS
# count                               2263.000000    2.263000e+03
# mean                                  23.190525    1.658016e+06
# std                                   21.564758    3.145187e+05
# min                                    1.000039    5.518900e+04
# 25%                                    1.899502    1.530014e+06
# 50%                                   16.221721    1.679030e+06
# 75%                                   42.590233    1.816857e+06
# max                                   74.411856    3.150313e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 19 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   STATE                                     2263 non-null   object
#  1   CONSTITUENCY                              2263 non-null   object
#  2   NAME                                      2263 non-null   object
#  3   WINNER                                    2263 non-null   int64
#  4   PARTY                                     2263 non-null   object
#  5   SYMBOL                                    2018 non-null   object
#  6   GENDER                                    2018 non-null   object
#  7   CRIMINAL CASES                            2018 non-null   object
#  8   AGE                                       2018 non-null   float64
#  9   CATEGORY                                  2018 non-null   object
#  10  EDUCATION                                 2018 non-null   object
#  11  ASSETS                                    2018 non-null   object
#  12  LIABILITIES                               2018 non-null   object
#  13  GENERAL VOTES                             2263 non-null   int64
#  14  POSTAL VOTES                              2263 non-null   int64
#  15  TOTAL VOTES                               2263 non-null   int64
#  16  OVER TOTAL ELECTORS  IN CONSTITUENCY      2263 non-null   float64
#  17  OVER TOTAL VOTES POLLED  IN CONSTITUENCY  2263 non-null   float64
#  18  TOTAL ELECTORS                            2263 non-null   int64
# dtypes: float64(3), int64(5), object(11)
# memory usage: 336.0+ KB

# %%
df.describe().columns
# Out:
# Index(['WINNER', 'AGE', 'GENERAL VOTES', 'POSTAL VOTES', 'TOTAL VOTES',
#        'OVER TOTAL ELECTORS  IN CONSTITUENCY',
#        'OVER TOTAL VOTES POLLED  IN CONSTITUENCY', 'TOTAL ELECTORS'],
#       dtype='object')

# %%
df['CRIMINAL CASES'] = df['CRIMINAL CASES'].fillna(0)
df['AGE'] = df['AGE'].fillna(0)
df['AGE'] = df['AGE'].astype(int)

# %%
indexNames = df[ df['PARTY'] == 'NOTA' ].index
df.drop(indexNames , inplace=True)
df
# Out:
#               STATE     CONSTITUENCY                    NAME  WINNER  PARTY  \
# 0         Telangana         ADILABAD          SOYAM BAPU RAO       1    BJP
# 1         Telangana         ADILABAD            Godam Nagesh       0    TRS
# 2         Telangana         ADILABAD           RATHOD RAMESH       0    INC
# 4     Uttar Pradesh             AGRA   Satyapal Singh Baghel       1    BJP
# 5     Uttar Pradesh             AGRA        Manoj Kumar Soni       0    BSP
# ...             ...              ...                     ...     ...    ...
# 2257    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede       0  PHJSP
# 2258    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod       0    IND
# 2259      Telangana        ZAHIRABAD               B.B.PATIL       1    TRS
# 2260      Telangana        ZAHIRABAD         MADAN MOHAN RAO       0    INC
# 2261      Telangana        ZAHIRABAD      BANALA LAXMA REDDY       0    BJP
#
#         SYMBOL  GENDER CRIMINAL CASES  AGE CATEGORY      EDUCATION  \
# 0        Lotus    MALE             52   52       ST      12th Pass
# 1          Car    MALE              0   54       ST  Post Graduate
# 2         Hand    MALE              3   52       ST      12th Pass
# 4        Lotus    MALE              5   58       SC      Doctorate
# 5     Elephant    MALE              0   47       SC  Post Graduate
# ...        ...     ...            ...  ...      ...            ...
# 2257   Whistle  FEMALE              0   28  GENERAL      10th Pass
# 2258      SHIP    MALE              0   43  GENERAL  Post Graduate
# 2259       Car    MALE             18   63  GENERAL       Graduate
# 2260      Hand    MALE              0   49  GENERAL  Post Graduate
# 2261     Lotus    MALE              3   47  GENERAL      12th Pass
#
#                                 ASSETS                  LIABILITIES  \
# 0            Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+
# 1          Rs 1,84,77,888\n ~ 1 Crore+      Rs 8,47,000\n ~ 8 Lacs+
# 2          Rs 3,64,91,000\n ~ 3 Crore+  Rs 1,53,00,000\n ~ 1 Crore+
# 4          Rs 7,42,74,036\n ~ 7 Crore+    Rs 86,06,522\n ~ 86 Lacs+
# 5        Rs 13,37,84,385\n ~ 13 Crore+  Rs 2,22,51,891\n ~ 2 Crore+
# ...                                ...                          ...
# 2257         Rs 11,68,500\n ~ 11 Lacs+         Rs 9,000\n ~ 9 Thou+
# 2258         Rs 48,90,000\n ~ 48 Lacs+    Rs 10,20,000\n ~ 10 Lacs+
# 2259  Rs 1,28,78,51,556\n ~ 128 Crore+  Rs 1,15,35,000\n ~ 1 Crore+
# 2260     Rs 90,36,63,001\n ~ 90 Crore+                     Rs 0\n ~
# 2261       Rs 5,85,77,327\n ~ 5 Crore+    Rs 52,50,000\n ~ 52 Lacs+
#
#       GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0            376892           482       377374
# 1            318665           149       318814
# 2            314057           181       314238
# 4            644459          2416       646875
# 5            434199          1130       435329
# ...             ...           ...          ...
# 2257          20563            57        20620
# 2258          14661            25        14686
# 2259         434066           178       434244
# 2260         427900           115       428015
# 2261         138731           216       138947
#
#       OVER TOTAL ELECTORS  IN CONSTITUENCY  \
# 0                                25.330684
# 1                                21.399929
# 2                                21.092771
# 4                                33.383823
# 5                                22.466390
# ...                                    ...
# 2257                              1.076097
# 2258                              0.766419
# 2259                             28.975369
# 2260                             28.559732
# 2261                              9.271379
#
#       OVER TOTAL VOTES POLLED  IN CONSTITUENCY  TOTAL ELECTORS
# 0                                    35.468248         1489790
# 1                                    29.964370         1489790
# 2                                    29.534285         1489790
# 4                                    56.464615         1937690
# 5                                    37.999125         1937690
# ...                                        ...             ...
# 2257                                  1.755157         1916185
# 2258                                  1.250060         1916185
# 2259                                 41.574183         1498666
# 2260                                 40.977823         1498666
# 2261                                 13.302678         1498666
#
# [2018 rows x 19 columns]

# %%
WINNER = df[df['WINNER'] == 1]
LOOSER = df[df['WINNER'] == 0][:2037]
WINNER.shape, LOOSER.shape 

df = WINNER
df = df.append(LOOSER)
df
# Out:
#               STATE     CONSTITUENCY                               NAME  \
# 0         Telangana         ADILABAD                     SOYAM BAPU RAO
# 4     Uttar Pradesh             AGRA              Satyapal Singh Baghel
# 7       Maharashtra       AHMADNAGAR  Dr. SUJAY RADHAKRISHNA VIKHEPATIL
# 10          Gujarat   AHMEDABAD EAST         Patel Hasmukhbhai Somabhai
# 12          Gujarat   AHMEDABAD WEST               DR. KIRIT P. SOLANKI
# ...             ...              ...                                ...
# 2256    Maharashtra  YAVATMAL-WASHIM             Parashram Bhaosing Ade
# 2257    Maharashtra  YAVATMAL-WASHIM             Vaishali Sudhakar Yede
# 2258    Maharashtra  YAVATMAL-WASHIM                 Anil Jayram Rathod
# 2260      Telangana        ZAHIRABAD                    MADAN MOHAN RAO
# 2261      Telangana        ZAHIRABAD                 BANALA LAXMA REDDY
#
#       WINNER  PARTY                 SYMBOL  GENDER CRIMINAL CASES  AGE  \
# 0          1    BJP                  Lotus    MALE             52   52
# 4          1    BJP                  Lotus    MALE              5   58
# 7          1    BJP                  Lotus    MALE              0   37
# 10         1    BJP                  Lotus    MALE              0   58
# 12         1    BJP                  Lotus    MALE              0   69
# ...      ...    ...                    ...     ...            ...  ...
# 2256       0    IND  Tractor Chalata Kisan    MALE              0   64
# 2257       0  PHJSP                Whistle  FEMALE              0   28
# 2258       0    IND                   SHIP    MALE              0   43
# 2260       0    INC                   Hand    MALE              0   49
# 2261       0    BJP                  Lotus    MALE              3   47
#
#      CATEGORY      EDUCATION                         ASSETS  \
# 0          ST      12th Pass      Rs 30,99,414\n ~ 30 Lacs+
# 4          SC      Doctorate    Rs 7,42,74,036\n ~ 7 Crore+
# 7     GENERAL      Doctorate  Rs 16,86,64,576\n ~ 16 Crore+
# 10    GENERAL         Others    Rs 7,46,99,690\n ~ 7 Crore+
# 12         SC  Post Graduate    Rs 8,94,74,039\n ~ 8 Crore+
# ...       ...            ...                            ...
# 2256  GENERAL  Post Graduate  Rs 18,73,01,769\n ~ 18 Crore+
# 2257  GENERAL      10th Pass      Rs 11,68,500\n ~ 11 Lacs+
# 2258  GENERAL  Post Graduate      Rs 48,90,000\n ~ 48 Lacs+
# 2260  GENERAL  Post Graduate  Rs 90,36,63,001\n ~ 90 Crore+
# 2261  GENERAL      12th Pass    Rs 5,85,77,327\n ~ 5 Crore+
#
#                     LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0       Rs 2,31,450\n ~ 2 Lacs+         376892           482       377374
# 4     Rs 86,06,522\n ~ 86 Lacs+         644459          2416       646875
# 7     Rs 26,23,964\n ~ 26 Lacs+         696961          7699       704660
# 10    Rs 62,52,577\n ~ 62 Lacs+         745810          4024       749834
# 12                     Rs 0\n ~         638241          3381       641622
# ...                         ...            ...           ...          ...
# 2256    Rs 4,17,919\n ~ 4 Lacs+          24447            52        24499
# 2257       Rs 9,000\n ~ 9 Thou+          20563            57        20620
# 2258  Rs 10,20,000\n ~ 10 Lacs+          14661            25        14686
# 2260                   Rs 0\n ~         427900           115       428015
# 2261  Rs 52,50,000\n ~ 52 Lacs+         138731           216       138947
#
#       OVER TOTAL ELECTORS  IN CONSTITUENCY  \
# 0                                25.330684
# 4                                33.383823
# 7                                37.856533
# 10                               41.384970
# 12                               39.044323
# ...                                    ...
# 2256                              1.278530
# 2257                              1.076097
# 2258                              0.766419
# 2260                             28.559732
# 2261                              9.271379
#
#       OVER TOTAL VOTES POLLED  IN CONSTITUENCY  TOTAL ELECTORS
# 0                                    35.468248         1489790
# 4                                    56.464615         1937690
# 7                                    58.425159         1861396
# 10                                   67.005462         1811851
# 12                                   64.211450         1643317
# ...                                        ...             ...
# 2256                                  2.085334         1916185
# 2257                                  1.755157         1916185
# 2258                                  1.250060         1916185
# 2260                                 40.977823         1498666
# 2261                                 13.302678         1498666
#
# [2018 rows x 19 columns]

# %% [markdown]
# # Total constituencies per state

# %%
constituencies_per_state = df.groupby('STATE')['CONSTITUENCY'].nunique().reset_index().sort_values('CONSTITUENCY',ascending = False)
constituencies_per_state
# Out:
#                         STATE  CONSTITUENCY
# 33              Uttar Pradesh            80
# 19                Maharashtra            48
# 35                West Bengal            42
# 4                       Bihar            40
# 30                 Tamil Nadu            38
# 18             Madhya Pradesh            29
# 15                  Karnataka            28
# 10                    Gujarat            26
# 28                  Rajasthan            25
# 1              Andhra Pradesh            25
# 25                     Odisha            21
# 16                     Kerala            20
# 31                  Telangana            17
# 3                       Assam            14
# 14                  Jharkhand            14
# 27                     Punjab            13
# 6                Chhattisgarh            11
# 11                    Haryana            10
# 23               NCT OF Delhi             7
# 13            Jammu & Kashmir             6
# 34                Uttarakhand             5
# 12           Himachal Pradesh             4
# 32                    Tripura             2
# 2           Arunachal Pradesh             2
# 21                  Meghalaya             2
# 20                    Manipur             2
# 9                         Goa             2
# 24                   Nagaland             1
# 26                 Puducherry             1
# 22                    Mizoram             1
# 7        Dadra & Nagar Haveli             1
# 29                     Sikkim             1
# 5                  Chandigarh             1
# 17                Lakshadweep             1
# 8                 Daman & Diu             1
# 0   Andaman & Nicobar Islands             1

# %%
df.PARTY.value_counts()
# Out:
# BJP       420
# INC       413
# IND       201
# BSP       163
# CPI(M)    100
#          ...
# BRPI        1
# AHNP        1
# BNDl        1
# BVA         1
# VCSMP       1
# Name: PARTY, Length: 132, dtype: int64

# %%
df.PARTY.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(df['AGE'],shade=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Parties with criminal cases

# %%
df = df[df['CRIMINAL CASES'] != "Not Available"]
df['CRIMINAL CASES'] = df['CRIMINAL CASES'].astype(int)
criminal_cases = df[(df['CRIMINAL CASES'] != 'NaN') & (df['CRIMINAL CASES'].notnull())]
criminal_cases = criminal_cases.groupby('PARTY')['CRIMINAL CASES'].sum().reset_index().sort_values('CRIMINAL CASES',ascending=False)
criminal_cases
# Out:
#      PARTY  CRIMINAL CASES
# 26     BJP             898
# 46     INC             734
# 35     BSP             175
# 38  CPI(M)             168
# 47     IND             131
# ..     ...             ...
# 30    BMUP               0
# 28    BLSD               0
# 96    RLTP               0
# 97   RMPOI               0
# 98   RSOSP               0
#
# [132 rows x 2 columns]

# %%
highest = criminal_cases.head(1)
lowest = criminal_cases.tail(1)
highest, lowest
# Out:
# (   PARTY  CRIMINAL CASES
#  26   BJP             898,
#      PARTY  CRIMINAL CASES
#  98  RSOSP               0)

# %% [markdown]
# BJP has highest criminal cases i.e. 898

# %% [markdown]
# # Party geting maximum seat

# %%
winning_candidates_per_party = df.groupby(['PARTY'])['WINNER'].sum().reset_index().sort_values('WINNER',ascending = False)
winning_candidates_per_party = winning_candidates_per_party[winning_candidates_per_party['WINNER'] > 1].head(1)
winning_candidates_per_party
# Out:
#    PARTY  WINNER
# 26   BJP     300

# %% [markdown]
# BJP got maximum seats i.e 300

# %% [markdown]
# # Oldest candidate won?

# %%
winners = df[df['WINNER']==1]
winners = winners.groupby('NAME')['AGE'].sum().reset_index().sort_values('AGE',ascending=False).head(1)
winners
# Out:
#                          NAME  AGE
# 123  DR. SHAFIQUR REHMAN BARQ   86

# %% [markdown]
# DR.SHAFIQUR REHMAN BARQ of age 86yrs was the oldest candidate won the election

# %% [markdown]
# # Youngest candidate won?

# %%
winners = df[df['WINNER']==1]
winners = winners.groupby('NAME')['AGE'].sum().reset_index().sort_values('AGE',ascending=False).tail(1)
winners
# Out:
#                  NAME  AGE
# 178  GODDETI. MADHAVI   26

# %% [markdown]
# GODDETI. MADHAVI of age 26yrs was the youngest candidate won the election

# %%
df['GENDER'] = df['GENDER'].fillna(0)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['GENDER'] = le.fit_transform(df['GENDER'])
df['PARTY'] = le.fit_transform(df['PARTY'])

# %%
df
# Out:
#               STATE     CONSTITUENCY                               NAME  \
# 0         Telangana         ADILABAD                     SOYAM BAPU RAO
# 4     Uttar Pradesh             AGRA              Satyapal Singh Baghel
# 7       Maharashtra       AHMADNAGAR  Dr. SUJAY RADHAKRISHNA VIKHEPATIL
# 10          Gujarat   AHMEDABAD EAST         Patel Hasmukhbhai Somabhai
# 12          Gujarat   AHMEDABAD WEST               DR. KIRIT P. SOLANKI
# ...             ...              ...                                ...
# 2256    Maharashtra  YAVATMAL-WASHIM             Parashram Bhaosing Ade
# 2257    Maharashtra  YAVATMAL-WASHIM             Vaishali Sudhakar Yede
# 2258    Maharashtra  YAVATMAL-WASHIM                 Anil Jayram Rathod
# 2260      Telangana        ZAHIRABAD                    MADAN MOHAN RAO
# 2261      Telangana        ZAHIRABAD                 BANALA LAXMA REDDY
#
#       WINNER  PARTY                 SYMBOL  GENDER  CRIMINAL CASES  AGE  \
# 0          1     26                  Lotus       1              52   52
# 4          1     26                  Lotus       1               5   58
# 7          1     26                  Lotus       1               0   37
# 10         1     26                  Lotus       1               0   58
# 12         1     26                  Lotus       1               0   69
# ...      ...    ...                    ...     ...             ...  ...
# 2256       0     47  Tractor Chalata Kisan       1               0   64
# 2257       0     85                Whistle       0               0   28
# 2258       0     47                   SHIP       1               0   43
# 2260       0     46                   Hand       1               0   49
# 2261       0     26                  Lotus       1               3   47
#
#      CATEGORY      EDUCATION                         ASSETS  \
# 0          ST      12th Pass      Rs 30,99,414\n ~ 30 Lacs+
# 4          SC      Doctorate    Rs 7,42,74,036\n ~ 7 Crore+
# 7     GENERAL      Doctorate  Rs 16,86,64,576\n ~ 16 Crore+
# 10    GENERAL         Others    Rs 7,46,99,690\n ~ 7 Crore+
# 12         SC  Post Graduate    Rs 8,94,74,039\n ~ 8 Crore+
# ...       ...            ...                            ...
# 2256  GENERAL  Post Graduate  Rs 18,73,01,769\n ~ 18 Crore+
# 2257  GENERAL      10th Pass      Rs 11,68,500\n ~ 11 Lacs+
# 2258  GENERAL  Post Graduate      Rs 48,90,000\n ~ 48 Lacs+
# 2260  GENERAL  Post Graduate  Rs 90,36,63,001\n ~ 90 Crore+
# 2261  GENERAL      12th Pass    Rs 5,85,77,327\n ~ 5 Crore+
#
#                     LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0       Rs 2,31,450\n ~ 2 Lacs+         376892           482       377374
# 4     Rs 86,06,522\n ~ 86 Lacs+         644459          2416       646875
# 7     Rs 26,23,964\n ~ 26 Lacs+         696961          7699       704660
# 10    Rs 62,52,577\n ~ 62 Lacs+         745810          4024       749834
# 12                     Rs 0\n ~         638241          3381       641622
# ...                         ...            ...           ...          ...
# 2256    Rs 4,17,919\n ~ 4 Lacs+          24447            52        24499
# 2257       Rs 9,000\n ~ 9 Thou+          20563            57        20620
# 2258  Rs 10,20,000\n ~ 10 Lacs+          14661            25        14686
# 2260                   Rs 0\n ~         427900           115       428015
# 2261  Rs 52,50,000\n ~ 52 Lacs+         138731           216       138947
#
#       OVER TOTAL ELECTORS  IN CONSTITUENCY  \
# 0                                25.330684
# 4                                33.383823
# 7                                37.856533
# 10                               41.384970
# 12                               39.044323
# ...                                    ...
# 2256                              1.278530
# 2257                              1.076097
# 2258                              0.766419
# 2260                             28.559732
# 2261                              9.271379
#
#       OVER TOTAL VOTES POLLED  IN CONSTITUENCY  TOTAL ELECTORS
# 0                                    35.468248         1489790
# 4                                    56.464615         1937690
# 7                                    58.425159         1861396
# 10                                   67.005462         1811851
# 12                                   64.211450         1643317
# ...                                        ...             ...
# 2256                                  2.085334         1916185
# 2257                                  1.755157         1916185
# 2258                                  1.250060         1916185
# 2260                                 40.977823         1498666
# 2261                                 13.302678         1498666
#
# [1996 rows x 19 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logReg = LogisticRegression()

# %%
X = df[['GENDER', 'CRIMINAL CASES', 'AGE', 'GENERAL VOTES',
       'POSTAL VOTES', 'TOTAL VOTES','TOTAL ELECTORS','PARTY']].values
Y = df[['WINNER']].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %%
logReg.fit(X_train,Y_train)
y_pred = logReg.predict(X_test)

# %%
logReg.score(X_test,Y_test)
# Out:
# 0.8877755511022044

# %% [markdown]
# # Random Forest Classifier

# %%
X = df[['GENDER', 'CRIMINAL CASES', 'AGE', 'GENERAL VOTES',
       'POSTAL VOTES', 'TOTAL VOTES','TOTAL ELECTORS','PARTY']].values
Y = df[['WINNER']].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train,Y_train)
rfc_pred = rfc.predict(X_test)

# %%
accuracy_score(Y_test,rfc_pred)
# Out:
# 0.8937875751503006

# %% [markdown]
# # KNN Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train,Y_train)
knn.score(X_test,Y_test)
# Out:
# 0.87374749498998
